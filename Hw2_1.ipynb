# %% [markdown]
# <a href="https://colab.research.google.com/github/olhaishchenko/-data_science/blob/master/Hw2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Прочитайте дані за допомогою методу read_html з таблиці "Коефіцієнт народжуваності в регіонах України (1950—2019)"

# %%
import pandas as pd
import numpy as np

df = pd.read_html("https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%B8#%D0%9D%D0%B0%D1%80%D0%BE%D0%B4%D0%B6%D1%83%D0%B2%D0%B0%D0%BD%D1%96%D1%81%D1%82%D1%8C",
                   match="Коефіцієнт народжуваності в регіонах України")[0]

# %% [markdown]
# Вивести перші рядки таблиці за допомогою методу head

# %%
df.head()
# Out:
#              Регіон   1950   1960   1970  1990  2000  2012 2014 2019
# 0              Крим  230.0  206.0  160.0   130    73   126    —    —
# 1         Вінницька  224.0  192.0  142.0   124    84   112  109   76
# 2         Волинська  247.0  250.0  179.0   153   112   148  141  101
# 3  Дніпропетровська  204.0  204.0  151.0   123    71   112  111   71
# 4          Донецька  271.0  214.0  140.0   109    61    98   82    —

# %% [markdown]
# Визначте кількість рядків та стовпців у датафреймі (атрибут shape)

# %%
df.shape[0]
# Out:
# 28

# %%
df.shape[1]
# Out:
# 9

# %% [markdown]
# Замініть у таблиці значення "—" на значення NaN

# %%
df.replace('—', np.nan, inplace=True)

# %%
repl_tables_drop = df
repl_tables_drop
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012 2014 2019
# 0                Крим  230.0  206.0  160.0   130    73   126  NaN  NaN
# 1           Вінницька  224.0  192.0  142.0   124    84   112  109   76
# 2           Волинська  247.0  250.0  179.0   153   112   148  141  101
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112  111   71
# 4            Донецька  271.0  214.0  140.0   109    61    98   82  NaN
# 5         Житомирська  261.0  223.0  159.0   129    89   122  120   79
# 6        Закарпатська  314.0  273.0  207.0   168   115   151  146  104
# 7          Запорізька  219.0  197.0  150.0   124    71   106  106   68
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124  122   88
# 9            Київська  204.0  189.0  156.0   123    73   122  121   80
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110  108   68
# 11          Луганська  262.0  235.0  144.0   116    62    96   51  NaN
# ...

# %% [markdown]
# Визначте типи всіх стовпців за допомогою dataframe.dtypes

# %%
repl_tables_drop.dtypes
# Out:
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990        int64
# 2000        int64
# 2012        int64
# 2014       object
# 2019       object
# dtype: object

# %% [markdown]
# Замініть типи нечислових колонок на числові. Підказка - це колонки, де знаходився символ "—"

# %%
# df['2014'] = df['2014'].astype(float, copy=True)
# df['2019'] = df['2019'].astype(float, copy=True)
df_only_numeric = repl_tables_drop.apply(pd.to_numeric, errors='ignore')

# %%
df_only_numeric.dtypes
# Out:
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990        int64
# 2000        int64
# 2012        int64
# 2014      float64
# 2019      float64
# dtype: object

# %% [markdown]
# Порахуйте, яка частка пропусків міститься в кожній колонці (використовуйте методи isnull та sum)

# %%
df_only_numeric.isnull().mean()
# Out:
# Регіон    0.000000
# 1950      0.071429
# 1960      0.035714
# 1970      0.035714
# 1990      0.000000
# 2000      0.000000
# 2012      0.000000
# 2014      0.071429
# 2019      0.142857
# dtype: float64

# %% [markdown]
# Видаліть з таблиці дані по всій країні, останній рядок таблиці

# %%
df_new = df_only_numeric.drop([27], axis=0)
df_new
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012   2014   2019
# 0                Крим  230.0  206.0  160.0   130    73   126    NaN    NaN
# 1           Вінницька  224.0  192.0  142.0   124    84   112  109.0   76.0
# 2           Волинська  247.0  250.0  179.0   153   112   148  141.0  101.0
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112  111.0   71.0
# 4            Донецька  271.0  214.0  140.0   109    61    98   82.0    NaN
# 5         Житомирська  261.0  223.0  159.0   129    89   122  120.0   79.0
# 6        Закарпатська  314.0  273.0  207.0   168   115   151  146.0  104.0
# 7          Запорізька  219.0  197.0  150.0   124    71   106  106.0   68.0
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124  122.0   88.0
# 9            Київська  204.0  189.0  156.0   123    73   122  121.0   80.0
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110  108.0   68.0
# ...

# %% [markdown]
# Замініть відсутні дані в стовпцях середніми значеннями цих стовпців (метод fillna)

# %%
df_new = df_new.fillna(df_new.mean())
# df_new = df_new.fillna({"1950": df_new["1950"].mean(), "1960": df_new["1960"].mean(), "1970": df_new["1970"].mean(), "2014": df_new["2014"].mean(), "2019": df_new["2019"].mean()})
df_new
# Out:
# <ipython-input-67-41abeac3af8a>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_new = df_new.fillna(df_new.mean())
#                Регіон    1950        1960   1970  1990  2000  2012    2014  \
# 0                Крим  230.00  206.000000  160.0   130    73   126  111.44
# 1           Вінницька  224.00  192.000000  142.0   124    84   112  109.00
# 2           Волинська  247.00  250.000000  179.0   153   112   148  141.00
# 3    Дніпропетровська  204.00  204.000000  151.0   123    71   112  111.00
# 4            Донецька  271.00  214.000000  140.0   109    61    98   82.00
# 5         Житомирська  261.00  223.000000  159.0   129    89   122  120.00
# 6        Закарпатська  314.00  273.000000  207.0   168   115   151  146.00
# ...

# %% [markdown]
# Отримайте список регіонів, де рівень народжуваності у 2019 році був вищим за середній по Україні

# %%
average_2019 = df_new["2019"].mean()
df_new[df_new["2019"] > average_2019]["Регіон"].tolist()
# Out:
# ['Волинська',
#  'Закарпатська',
#  'Івано-Франківська',
#  'Львівська',
#  'Одеська',
#  'Рівненська',
#  'Херсонська',
#  'Чернівецька',
#  'Київ']

# %% [markdown]
# У якому регіоні була найвища народжуваність у 2014 році?

# %%
df_new.loc[df_new["2014"].idxmax()]["Регіон"]
# Out:
# 'Рівненська'

# %% [markdown]
# Побудуйте стовпчикову діаграму народжуваності по регіонах у 2019 році

# %%
import matplotlib.pyplot as plt
plt.rcdefaults()
fig, ax = plt.subplots()

ax.barh(df_new["Регіон"], df_new["2019"])
ax.set_title('How many birth people in 2019?');

# %%
plt.figure(figsize=(12, 10))
plt.pie(df_new["1950"], labels=df_new["Регіон"], autopct="%.2f%%", pctdistance=1.05, labeldistance=1.15);
plt.title('How many birth people in 1950 in different region?')
plt.tight_layout()
plt.show();

# %%
df_krym = df_new[df_new["Регіон"]=='Крим']
df_dnipro = df_new[df_new["Регіон"]=='Дніпропетровська']
df_chern = df_new[df_new["Регіон"]=='Чернігівська']

# %%
x=[1950, 1960 , 1970, 1990, 2000, 2012, 2014, 2019]
y_krym = [df_krym['1950'], df_krym['1960'], df_krym['1970'], df_krym['1990'], df_krym['2000'], df_krym['2012'], df_krym['2014'], df_krym['2019']]
y_dnipro = [df_dnipro['1950'], df_dnipro['1960'], df_dnipro['1970'], df_dnipro['1990'], df_dnipro['2000'], df_dnipro['2012'], df_dnipro['2014'], df_dnipro['2019']]
y_chern =[df_chern['1950'], df_chern['1960'], df_chern['1970'], df_chern['1990'], df_chern['2000'], df_chern['2012'], df_chern['2014'], df_chern['2019']]
fig, axs = plt.subplots()
axs.plot(x, y_krym , label='Krym')
axs.plot(x, y_dnipro , label='Dnipro')
axs.plot(x, y_chern , label='Chernihiv')
plt.xlabel('Year', fontsize='small', color='midnightblue')
plt.ylabel('Birth', fontsize='small', color='midnightblue')
plt.legend()
axs.set_title('Krym, Dnipro, Chernihiv in 1950');

# %%
import seaborn as sns
sns.violinplot(x=df_new['1990'], y=df_new['Регіон'])
plt.title('Ukraine 1990');
